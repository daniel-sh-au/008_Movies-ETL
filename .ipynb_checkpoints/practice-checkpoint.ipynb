# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = 'C:/Users/danie/OneDrive/Desktop/UofT_DataBootCamp/Module08_SQL_ETL/UofT_DataBC_Module08_Movies-ETL'

# %%
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records
wiki_movies_raw[:5]
# Last 5 records
wiki_movies_raw[-5:]
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.sample()
# Out:
#                                                     url    year  \
# 4908  https://en.wikipedia.org/wiki/The_Other_Boleyn...  2008.0
#
#                                   imdb_link                  title  \
# 4908  https://www.imdb.com/title/tt0467200/  The Other Boleyn Girl
#
#           Directed by  Produced by Screenplay by Story by  \
# 4908  Justin Chadwick  Alison Owen  Peter Morgan      NaN
#
#                                            Based on  \
# 4908  [The Other Boleyn Girl, by, Philippa Gregory]
#
#                                                Starring  ... Predecessor  \
# 4908  [Natalie Portman, Scarlett Johansson, Eric Ban...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 4908      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 4908              NaN    NaN
#
# [1 rows x 193 columns]

# %%
wiki_movies_df.columns.to_list()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
# Extracting Sample Data
#kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
#ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
#print(kaggle_metadata.head())
#print(kaggle_metadata.tail())
#print(kaggle_metadata.sample(n=1))

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
wiki_movies_df2 = pd.DataFrame(wiki_movies)
wiki_movies_df2.sample()
# Out:
#                                             url  year  \
# 2209  https://en.wikipedia.org/wiki/Hope_Floats  1998
#
#                                   imdb_link        title      Directed by  \
# 2209  https://www.imdb.com/title/tt0119313/  Hope Floats  Forest Whitaker
#
#                                             Produced by Screenplay by  \
# 2209  [Lynda Obst, Sandra Bullock, Elizabeth Joan Ho...           NaN
#
#      Story by Based on                                           Starring  \
# 2209      NaN      NaN  [Sandra Bullock, Harry Connick Jr., Gena Rowla...
#
#       ... Hepburn Literally Cantonese Chinese Yiddish Arabic Romanized  \
# 2209  ...     NaN       NaN       NaN     NaN     NaN    NaN       NaN
#
#      Russian Hebrew Polish
# 2209     NaN    NaN    NaN
#
# [1 rows x 75 columns]
